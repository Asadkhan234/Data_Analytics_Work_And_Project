# %%
import pandas as pd

# %%
data = pd.read_csv('Customers_Data.csv',encoding="latin1")
data
# Out:
#        CustomerKey Prefix  FirstName LastName   BirthDate MaritalStatus  \
# 0            11000    MR.        JON     YANG    4/8/1966             M
# 1            11001    MR.     EUGENE    HUANG   5/14/1965             S
# 2            11002    MR.      RUBEN   TORRES   8/12/1965             M
# 3            11003    MS.    CHRISTY      ZHU   2/15/1968             S
# 4            11004   MRS.  ELIZABETH  JOHNSON    8/8/1968             S
# ...            ...    ...        ...      ...         ...           ...
# 18143        29479    MR.      TOMMY     TANG    7/4/1958             M
# 18144        29480   MRS.       NINA     RAJI  11/10/1960             S
# 18145        29481    MR.       IVAN     SURI    1/5/1960             S
# 18146        29482    MR.    CLAYTON    ZHANG    3/5/1959             M
# 18147        29483    MR.      JÉSUS  NAVARRO   12/8/1959             M
#
#       Gender                    EmailAddress AnnualIncome  TotalChildren  \
# ...

# %% [markdown]
# # Exploring data:

# %%
data.head()
# Out:
#    CustomerKey Prefix  FirstName LastName  BirthDate MaritalStatus Gender  \
# 0        11000    MR.        JON     YANG   4/8/1966             M      M
# 1        11001    MR.     EUGENE    HUANG  5/14/1965             S      M
# 2        11002    MR.      RUBEN   TORRES  8/12/1965             M      M
# 3        11003    MS.    CHRISTY      ZHU  2/15/1968             S      F
# 4        11004   MRS.  ELIZABETH  JOHNSON   8/8/1968             S      F
#
#                      EmailAddress AnnualIncome  TotalChildren EducationLevel  \
# 0       jon24@adventure-works.com     $90,000               2      Bachelors
# 1    eugene10@adventure-works.com     $60,000               3      Bachelors
# 2     ruben35@adventure-works.com     $60,000               3      Bachelors
# 3   christy12@adventure-works.com     $70,000               0      Bachelors
# 4  elizabeth5@adventure-works.com     $80,000               5      Bachelors
#
#      Occupation HomeOwner
# 0  Professional         Y
# ...

# %%
data.tail()
# Out:
#        CustomerKey Prefix FirstName LastName   BirthDate MaritalStatus Gender  \
# 18143        29479    MR.     TOMMY     TANG    7/4/1958             M      M
# 18144        29480   MRS.      NINA     RAJI  11/10/1960             S      F
# 18145        29481    MR.      IVAN     SURI    1/5/1960             S      M
# 18146        29482    MR.   CLAYTON    ZHANG    3/5/1959             M      M
# 18147        29483    MR.     JÉSUS  NAVARRO   12/8/1959             M      M
#
#                        EmailAddress AnnualIncome  TotalChildren  \
# 18143    tommy2@adventure-works.com     $30,000               1
# 18144    nina21@adventure-works.com     $30,000               3
# 18145     ivan0@adventure-works.com     $30,000               3
# 18146  clayton0@adventure-works.com     $30,000               3
# 18147    jésus9@adventure-works.com     $30,000               0
#
#         EducationLevel Occupation HomeOwner
# 18143  Graduate Degree   Clerical         Y
# ...

# %%
data.describe()
# Out:
#         CustomerKey  TotalChildren
# count  18148.000000   18148.000000
# mean   20247.470465       1.843619
# std     5336.245656       1.613203
# min    11000.000000       0.000000
# 25%    15626.750000       0.000000
# 50%    20252.500000       2.000000
# 75%    24868.250000       3.000000
# max    29483.000000       5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18148 entries, 0 to 18147
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerKey     18148 non-null  int64
#  1   Prefix          18018 non-null  object
#  2   FirstName       18148 non-null  object
#  3   LastName        18148 non-null  object
#  4   BirthDate       18148 non-null  object
#  5   MaritalStatus   18148 non-null  object
#  6   Gender          18018 non-null  object
#  7   EmailAddress    18148 non-null  object
#  8   AnnualIncome    18148 non-null  object
#  9   TotalChildren   18148 non-null  int64
#  10  EducationLevel  18148 non-null  object
#  11  Occupation      18148 non-null  object
#  12  HomeOwner       18148 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 1.8+ MB

# %%
data.isna()
# Out:
#        CustomerKey  Prefix  FirstName  LastName  BirthDate  MaritalStatus  \
# 0            False   False      False     False      False          False
# 1            False   False      False     False      False          False
# 2            False   False      False     False      False          False
# 3            False   False      False     False      False          False
# 4            False   False      False     False      False          False
# ...            ...     ...        ...       ...        ...            ...
# 18143        False   False      False     False      False          False
# 18144        False   False      False     False      False          False
# 18145        False   False      False     False      False          False
# 18146        False   False      False     False      False          False
# 18147        False   False      False     False      False          False
#
#        Gender  EmailAddress  AnnualIncome  TotalChildren  EducationLevel  \
# ...

# %%
data.isnull().sum()
# Out:
# CustomerKey         0
# Prefix            130
# FirstName           0
# LastName            0
# BirthDate           0
# MaritalStatus       0
# Gender            130
# EmailAddress        0
# AnnualIncome        0
# TotalChildren       0
# EducationLevel      0
# Occupation          0
# HomeOwner           0
# dtype: int64

# %%
data[data.Prefix.isnull()]
# Out:
#        CustomerKey Prefix  FirstName   LastName   BirthDate MaritalStatus  \
# 24           11025    NaN  ALEJANDRO       BECK  12/23/1945             M
# 34           11035    NaN      WENDY  DOMINGUEZ   2/24/1948             M
# 81           11082    NaN     ANGELA     BUTLER    8/4/1966             S
# 228          11234    NaN       ANNA    GRIFFIN  11/19/1952             S
# 464          11475    NaN      CESAR     SUBRAM   10/9/1978             S
# ...            ...    ...        ...        ...         ...           ...
# 17655        28981    NaN       LUKE        JAI   3/17/1940             S
# 17673        28999    NaN     EDWARD   MARTINEZ  10/24/1947             M
# 17806        29136    NaN   CAROLINE     BRYANT    5/8/1964             M
# 18012        29345    NaN    RANDALL       DIAZ   2/26/1942             S
# 18112        29448    NaN    LINDSEY       YUAN  11/28/1941             S
#
#       Gender                     EmailAddress AnnualIncome  TotalChildren  \
# ...

# %% [markdown]
# # Handling Duplicates :
# - we can drop duplicates just of primery key or according to column means the data avalible should be appaer one time

# %%
data = pd.read_csv('company1.csv')
data
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN
# 6  EMP02     rohit      M  25000.0

# %%
data[data.duplicated()]
# Out:
#     EEID   Name gender   salary
# 6  EMP02  rohit      M  25000.0

# %%
data[data.EEID.duplicated()]
# Out:
#     EEID    Name gender   salary
# 3  EMP01  ayushi      F  20000.0
# 6  EMP02   rohit      M  25000.0

# %%
print(data['EEID'].duplicated().sum())
# Out:
# 2

# %%
data = data.drop_duplicates('EEID')

# %%
data
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN

# %%
data = data.drop_duplicates('Name')

# %%
data
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 4  EMP05       NaN      M  25000.0

# %% [markdown]
# # Handling Null values :

# %%
data = pd.read_csv('company1.csv')
data
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN
# 6  EMP02     rohit      M  25000.0

# %%
# using replace method:
import numpy as np
data.replace(np.nan,30000)
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F  30000.0
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali  30000  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05     30000      M  25000.0
# 5  EMP06     rohit      M  30000.0
# 6  EMP02     rohit      M  25000.0

# %%
# There is an error it can fill all the rows from the given value Eithir it is object or integer.

# %%
data
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN
# 6  EMP02     rohit      M  25000.0

# %%
# Here using replace but for single col salary :
data['salary'] = data['salary'].replace(np.nan,data['salary'].mean())
data
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F  24400.0
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M  24400.0
# 6  EMP02     rohit      M  25000.0

# %%
# Now want to handle object to fill . Using method (bfill and ffill):
#data[['Name','gender']] = data[['Name','gender']].bfill()

# %%
data
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F  24400.0
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M  24400.0
# 6  EMP02     rohit      M  25000.0

# %%
# Now want to handle object to fill . Using method (bfill and ffill):
#data[['Name','gender']] = data[['Name','gender']].ffill()

# %%
data
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F  24400.0
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M  24400.0
# 6  EMP02     rohit      M  25000.0

# %%
data.fillna(method='bfill')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14008\1397359497.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F  24400.0
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali      F  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05     rohit      M  25000.0
# 5  EMP06     rohit      M  24400.0
# 6  EMP02     rohit      M  25000.0

# %%
data.fillna(method='ffill')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14008\1844443866.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali      M  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05    ayushi      M  25000.0
# 5  EMP06     rohit      M  25000.0
# 6  EMP02     rohit      M  25000.0
